# %%
conda install -c conda-forge pydicom
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\bilge\anaconda3
#
#   added / updated specs:
#     - pydicom
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1q             |       h8ffe710_0         5.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.07.19~ --> conda-forge::ca-certificates-2022.6.15-h5b45459_0
#   certifi            pkgs/main::certifi-2022.6.15-py39haa9~ --> conda-forge::certifi-2022.6.15-py39hcbf5309_0
#   openssl              pkgs/main::openssl-1.1.1q-h2bbff1b_0 --> conda-forge::openssl-1.1.1q-h8ffe710_0
#
#
#
# ...
#
# ...

# %%
import pydicom as dicom
import matplotlib.pylab as plt
import glob

# %%
for klasor_path in glob.glob("Test\*"):
    print(len(klasor_path))
import os
subdirname = os.listdir(r"C:\Users\bilge\OneDrive\Desktop\SYZ\Test")
subdirname
counter = 0
counter2 = 0
counter3 = 0
veri=[]
for i in subdirname:
    path=f'C:/Users/bilge/OneDrive/Desktop/SYZ/Test/{i}'
    counter3 = counter3 + 1
    for n in os.listdir(path):
        counter2 = counter2 + 1
    
        for file_path in glob.glob(f'Test\{i}\{n}\*.dcm'):
            
            counter = counter + 1
            #file_path = 'C:\\Users\\bilge\\OneDrive\\Desktop\\asd\\' + str(file_path)
            file_path=file_path.replace("\\","/")
            veri.append(file_path)
print(counter3)
print(counter2)
print(counter)
# Out:
# 10
# 12
# 10
# 10
# 10
# 10
# 17
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3452/431290853.py in <module>
#      11     path=f'C:/Users/bilge/OneDrive/Desktop/SYZ/Test/{i}'
#      12     counter3 = counter3 + 1
# ---> 13     for n in os.listdir(path):
#      14         counter2 = counter2 + 1
#      15
#
# NotADirectoryError: [WinError 267] Dizin adı geçersiz: 'C:/Users/bilge/OneDrive/Desktop/SYZ/Test/filelist.txt'

# %%
# Out:
# ['Test/10244/Seri2/38767510172.dcm',
#  'Test/10244/Seri2/38767510173.dcm',
#  'Test/10244/Seri2/38767510174.dcm',
#  'Test/10244/Seri2/38767510175.dcm',
#  'Test/10244/Seri2/38767510176.dcm',
#  'Test/10244/Seri2/38767510177.dcm',
#  'Test/10244/Seri2/38767510178.dcm',
#  'Test/10244/Seri2/38767510179.dcm',
#  'Test/10244/Seri2/38767510180.dcm',
#  'Test/10244/Seri2/38767510181.dcm',
#  'Test/10244/Seri2/38767510182.dcm',
#  'Test/10244/Seri2/38767510183.dcm',
#  'Test/10244/Seri2/38767510184.dcm',
#  'Test/10244/Seri2/38767510185.dcm',
#  'Test/10244/Seri2/38767510186.dcm',
#  'Test/10244/Seri2/38767510187.dcm',
#  'Test/10244/Seri2/38767510188.dcm',
#  'Test/10244/Seri2/38767510189.dcm',
#  'Test/10244/Seri2/38767510190.dcm',
#  'Test/10244/Seri2/38767510191.dcm',
#  'Test/10244/Seri2/38767510192.dcm',
#  'Test/10244/Seri2/38767510193.dcm',
#  'Test/10244/Seri2/38767510194.dcm',
#  'Test/10244/Seri2/38767510195.dcm',
#  'Test/10244/Seri2/38767510196.dcm',
# ...

# %%
import cv2
import os
from PIL import Image
import numpy as np
outdir = ''
#for f in Fseries:   
newpath='asdadsads'
counter=0
long_name_veri=[]
for i in veri:
    
    if len(i)==36:
        path = 'test_'+i[8:20]
        if newpath !=path:
            os.makedirs(path)
            newpath=path
            counter = counter +1
            print(counter,path)
    else:
        path = 'test_'+i[8:22]
        if newpath !=path:
            os.makedirs(path)
            newpath=path
            counter = counter +1
            print(counter,path)
#170-252
# Out:
# 1 test_44/Seri2/38767
# 2 test_7975/Seri2/301
# 3 test_82/Seri3/38024
# 4 test_24/Seri3/34806
# 5 test_80/Seri1/33654
# 6 test_85/Seri3/33552

# %%
for i in veri:
    path = i[-15:]
    print(path)
# Out:
# 38767510172.dcm
# 38767510173.dcm
# 38767510174.dcm
# 38767510175.dcm
# 38767510176.dcm
# 38767510177.dcm
# 38767510178.dcm
# 38767510179.dcm
# 38767510180.dcm
# 38767510181.dcm
# 38767510182.dcm
# 38767510183.dcm
# 38767510184.dcm
# 38767510185.dcm
# 38767510186.dcm
# 38767510187.dcm
# 38767510188.dcm
# 38767510189.dcm
# 38767510190.dcm
# 38767510191.dcm
# 38767510192.dcm
# 38767510193.dcm
# 38767510194.dcm
# 38767510195.dcm
# 38767510196.dcm
# 38767510197.dcm
# 38767510198.dcm
# 38767510199.dcm
# 38767510200.dcm
# 38767510201.dcm
# 38767510202.dcm
# 38767510203.dcm
# 38767510204.dcm
# 38767510205.dcm
# 38767510206.dcm
# 38767510207.dcm
# 38767510208.dcm
# 38767510209.dcm
# 38767510210.dcm
# 38767510211.dcm
# 38767510212.dcm
# 38767510213.dcm
# 38767510214.dcm
# 38767510215.dcm
# 38767510216.dcm
# 38767510217.dcm
# 38767510218.dcm
# 38767510219.dcm
# 38767510220.dcm
# 38767510221.dcm
# 38767510222.dcm
# 38767510223.dcm
# 38767510224.dcm
# 38767510225.dcm
# 38767510226.dcm
# ...

# %%
import os
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings(action="ignore")
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report
#tensorflow libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D, Dense, Dropout,Flatten, Conv2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import TensorBoard,EarlyStopping 
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
tf.debugging.set_log_device_placement(True)
# Out:
# Num GPUs Available:  0

# %%
Data=pd.read_('BasBit.xlsx')

# %%
# Out:
# 'Test\\10244\\Seri2\\0     38767510201\n1     38767510208\n2     38767510209\n3     38767510229\n4     38767510238\n         ...     \n67    33552821318\n68    33552821415\n69    33552821458\n70    33552821459\n71    33552821558\nName: Kesit Numarası, Length: 72, dtype: int64.dcm'

# %%
import time
import pylibjpeg
from pydicom import dcmread
from PIL import Image
from pydicom.data import get_testdata_file
counter = 0
c = 0

for i in veri:
    path = 'test_'+i[4:-4]
    ds = dicom.dcmread(i) # read dicom image

    new_image = ds.pixel_array.astype(float)
    scaled_image = (np.maximum(new_image, 0) / new_image.max()) * 255.0
    scaled_image = np.uint8(scaled_image)
    final_image = Image.fromarray(scaled_image)

    final_image.save(path+'.jpg')
    counter = counter +1

    veri.remove(i)
    if counter >100:
        c= c+1
        time.sleep(2)
        counter=0
        print('sleeping', c)

# %%
c=0
for i in veri_csv_:
    print(c,'            ',i)
    c=c+1

# %%
"""aaaa=veri_csv_[424:492]
for i in aaaa:
    veri_csv_.remove(i)"""

# %%
print(len(veri))
# Out:
# 0

# %%
with open("verison.txt", 'w') as f:
    for s in veri:
        f.write(str(s) + '\n')

# %%
txt", 'w') as f:
    for s in veri:
        f.write(str(s) + '\n')

# %%
# Out:
# sleeping 1
# sleeping 2
# sleeping 3
# sleeping 4
# sleeping 5
# sleeping 6
# sleeping 7
# sleeping 8
# sleeping 9
# sleeping 10
# sleeping 11
# sleeping 12
# sleeping 13
# sleeping 14
# sleeping 15
# sleeping 16
# sleeping 17
# sleeping 18
# sleeping 19
# sleeping 20
# sleeping 21
# sleeping 22
# sleeping 23
# sleeping 24
# sleeping 25
# sleeping 26
# sleeping 27
# sleeping 28
# sleeping 29
# sleeping 30
# sleeping 31
# sleeping 32
# sleeping 33
# sleeping 34
# sleeping 35
# sleeping 36
# sleeping 37
# sleeping 38
# sleeping 39
# sleeping 40
# sleeping 41
# sleeping 42
# sleeping 43
# sleeping 44
# sleeping 45
# sleeping 46
# sleeping 47
# sleeping 48
# sleeping 49
# sleeping 50
# sleeping 51
# sleeping 52
# sleeping 53
# sleeping 54
# sleeping 55
# sleeping 56
# sleeping 57
# sleeping 58
# sleeping 59
# sleeping 60
# sleeping 61
# sleeping 62
# sleeping 63
# sleeping 64
# sleeping 65
# sleeping 66
# sleeping 67
# sleeping 68
# sleeping 69
# sleeping 70
# sleeping 71
# sleeping 72
# ...

# %%
print(len(veri))
# Out:
# 11212

# %%
with open("verison4.txt", 'w') as f:
    for s in veri:
        f.write(str(s) + '\n')

# %%
# Out:
# sleeping 1
# sleeping 2
# sleeping 3
# sleeping 4
# sleeping 5
# sleeping 6
# sleeping 7
# sleeping 8
# sleeping 9
# sleeping 10
# sleeping 11
# sleeping 12
# sleeping 13
# sleeping 14
# sleeping 15
# sleeping 16
# sleeping 17
# sleeping 18
# sleeping 19
# sleeping 20
# sleeping 21
# sleeping 22
# sleeping 23
# sleeping 24
# sleeping 25
# sleeping 26
# sleeping 27
# sleeping 28
# sleeping 29
# sleeping 30
# sleeping 31
# sleeping 32
# sleeping 33
# sleeping 34
# sleeping 35
# sleeping 36
# sleeping 37
# sleeping 38
# sleeping 39
# sleeping 40
# sleeping 41
# sleeping 42
# sleeping 43
# sleeping 44
# sleeping 45
# sleeping 46
# sleeping 47
# sleeping 48
# sleeping 49
# sleeping 50
# sleeping 51
# sleeping 52
# sleeping 53
# sleeping 54
# sleeping 55

# %%
print(len(veri))
# Out:
# 5606

# %%
with open("verison5.txt", 'w') as f:
    for s in veri:
        f.write(str(s) + '\n')

# %%
# Out:
# sleeping 1
# sleeping 2
# sleeping 3
# sleeping 4
# sleeping 5
# sleeping 6
# sleeping 7
# sleeping 8
# sleeping 9
# sleeping 10
# sleeping 11
# sleeping 12
# sleeping 13
# sleeping 14
# sleeping 15
# sleeping 16
# sleeping 17
# sleeping 18
# sleeping 19
# sleeping 20
# sleeping 21
# sleeping 22
# sleeping 23
# sleeping 24
# sleeping 25
# sleeping 26
# sleeping 27

# %%
print(len(veri))
# Out:
# 2803

# %%
with open("verison6.txt", 'w') as f:
    for s in veri:
        f.write(str(s) + '\n')

# %%
# Out:
# sleeping 1
# sleeping 2
# sleeping 3
# sleeping 4
# sleeping 5
# sleeping 6
# sleeping 7
# sleeping 8
# sleeping 9
# sleeping 10
# sleeping 11
# sleeping 12
# sleeping 13

# %%
print(len(veri))
# Out:
# 1401

# %%
with open("verison6.txt", 'w') as f:
    for s in veri:
        f.write(str(s) + '\n')

# %%
print(len(veri))
# Out:
# 0

# %%
with open("verison6.txt", 'w') as f:
    for s in veri:
        f.write(str(s) + '\n')
